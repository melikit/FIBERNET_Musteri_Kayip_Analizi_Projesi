# %%
import numpy 
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
veri = pd.read_excel("nufus-bilgileri.xlsx")
print(df.head())
# Out:
#     Yıl          İlçe  ilce_kodu  Erkek ve 0-4  Erkek ve 5-9  Erkek ve 10-14  \
# 0  2007        Adalar       1103           236           293             314
# 1  2007       Avcılar       2003         12458         13222           13157
# 2  2007      Bağcılar       2004         34607         37663           35723
# 3  2007  Bahçelievler       2005         21638         23380           23962
# 4  2007      Bakırköy       1166          4956          5151            5966
#
#    Erkek ve 15-19  Erkek ve 20-24  Erkek ve 25-29  Erkek ve 30-34  ...  \
# 0             395             576             473             422  ...
# 1           13647           13730           18458           16318  ...
# 2           34430           28730           41713           36585  ...
# 3           24233           22535           31775           28338  ...
# 4            7118            9099            9155            8223  ...
#
#    Kadın ve 45-49  Kadın ve 50-54  Kadın ve 55-59  Kadın ve 60-64  \
# ...

# %%
veri.columns
# Out:
# Index(['Yıl', 'İlçe', 'ilce_kodu', 'Erkek ve 0-4', 'Erkek ve 5-9',
#        'Erkek ve 10-14', 'Erkek ve 15-19', 'Erkek ve 20-24', 'Erkek ve 25-29',
#        'Erkek ve 30-34', 'Erkek ve 35-39', 'Erkek ve 40-44', 'Erkek ve 45-49',
#        'Erkek ve 50-54', 'Erkek ve 55-59', 'Erkek ve 60-64', 'Erkek ve 65-69',
#        'Erkek ve 70-74', 'Erkek ve 75-79', 'Erkek ve 80-84', 'Erkek ve 85-89',
#        'Erkek ve 90+', 'Kadın ve 0-4', 'Kadın ve 5-9', 'Kadın ve 10-14',
#        'Kadın ve 15-19', 'Kadın ve 20-24', 'Kadın ve 25-29', 'Kadın ve 30-34',
#        'Kadın ve 35-39', 'Kadın ve 40-44', 'Kadın ve 45-49', 'Kadın ve 50-54',
#        'Kadın ve 55-59', 'Kadın ve 60-64', 'Kadın ve 65-69', 'Kadın ve 70-74',
#        'Kadın ve 75-79', 'Kadın ve 80-84', 'Kadın ve 85-89', 'Kadın ve 90+'],
#       dtype='object')

# %% [raw]
# print(veri.isnull().sum())

# %%
veri.info()
veri.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 41 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Yıl             695 non-null    int64
#  1   İlçe            695 non-null    object
#  2   ilce_kodu       695 non-null    int64
#  3   Erkek ve 0-4    695 non-null    int64
#  4   Erkek ve 5-9    695 non-null    int64
#  5   Erkek ve 10-14  695 non-null    int64
#  6   Erkek ve 15-19  695 non-null    int64
#  7   Erkek ve 20-24  695 non-null    int64
#  8   Erkek ve 25-29  695 non-null    int64
#  9   Erkek ve 30-34  695 non-null    int64
#  10  Erkek ve 35-39  695 non-null    int64
#  11  Erkek ve 40-44  695 non-null    int64
#  12  Erkek ve 45-49  695 non-null    int64
#  13  Erkek ve 50-54  695 non-null    int64
#  14  Erkek ve 55-59  695 non-null    int64
#  15  Erkek ve 60-64  695 non-null    int64
#  16  Erkek ve 65-69  695 non-null    int64
# ...

# %%
Erkek=veri.filter(like="Erkek").columns
Kadın=veri.filter(like="Kadın").columns
plt.figure(figsize=(10,5))
erkek_toplam = df[Erkek].sum(axis=1).hist(bins=15, color="red", edgecolor="black")
plt.title("erkeklerin yaşlara göre dağılımı")
plt.xlabel("YAŞ")
plt.ylabel("NÜFUS")
plt.show()
